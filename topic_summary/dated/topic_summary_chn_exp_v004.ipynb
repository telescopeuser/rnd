# %% [markdown]
# # Chinese text summarization algorithm
# ### www.KudosData.com
# #### By: Sam GU Zhan
# #### March, 2017

# %% [markdown]
# # Imports

# %%
# coding=UTF-8
from __future__ import division
import re

# Python2 unicode & float-division support:
# from __future__ import unicode_literals, division

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

import io

# 中文字符和语言处理库
import jieba

# 机器学习库 sklearn 分类学习模型库
#from sklearn import linear_model
from sklearn.feature_extraction import DictVectorizer # 数据结构变换：把 Dict 转换为 稀疏矩阵
# from sklearn.linear_model import LogisticRegression  # 逻辑回归分类模型
# from sklearn.pipeline import make_pipeline # 封装机器学习模型流程
# from sklearn.metrics import confusion_matrix, roc_curve, auc

# 中文显示设置
from pylab import *  
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体  
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题 
mpl.rcParams['font.size'] = 14 # 设置字体大小

np.random.seed(88)

# %% [markdown]
# # Define Functions

# %%
# Python3
# 中文分词功能小函数， 输出 字符串， 各词组由空格分隔
def KudosData_word_tokenizer(foo):
    # remove lead & tail spaces firstly:
    foo = foo.strip()
    seg_token = jieba.cut(str(foo), cut_all=True)
    seg_str = str(' '.join(seg_token)).strip()

    return seg_str
# Python2
# 中文分词功能小函数， 输出 字符串， 各词组由空格分隔
# def KudosData_word_tokenizer(foo):
#     seg_token = jieba.cut(foo, cut_all=True)
#     seg_str = ' '.join(seg_token)
#     return seg_str

# %%
# Python3
# 中文分词功能小函数， 输出 dictionary： { key 词组， value 计数 }
def KudosData_word_count(foo):
    # remove lead & tail spaces firstly:
    foo = foo.strip()
    seg_token = jieba.cut(str(foo), cut_all=True)
    seg_str = str(' '.join(seg_token)).strip()
    seg_count = pd.value_counts(str(seg_str).lower().split(' '))
    seg_count = seg_count.to_dict() 
    seg_count.pop('', None) # remove EMPTY dict key: ''
    return seg_count
# Python2
# 中文分词功能小函数， 输出 dictionary： { key 词组， value 计数 }
# def KudosData_word_count(foo):
#     seg_token = jieba.cut(foo, cut_all=True)
#     seg_str = '^'.join(seg_token)
#     seg_count = pd.value_counts(seg_str.lower().split('^'))
#     return seg_count.to_dict()

# %% [markdown]
# # Input text

# %%
# process Unicode text input
with io.open('input_text.txt','r',encoding='utf8') as f:
    text = f.read()

content = text

title = '''
<Dummy Title>
'''

# %%
# content

# %%
def format_sentence(text):
#     sentence = re.sub(r'\W+', '#', sentence)
    text = re.sub(r'\t+', '', text) # remove one or more Tab
    return text

# %%
def linebreak_conversion_win_linux(text):
    text = re.sub(r'\r', '', text) # remove one or more Tab
    text = re.sub(r'\u3000', ' ', text) # convert white space: \u3000    
    return text

# %%
def clean_some_whitespace(text): # Does not remove normal Space
#     sentence = re.sub(r'\W+', '#', sentence)
    text = re.sub(r'\t+', '', text) # remove one or more Tab
    text = re.sub(r'\f+', '', text) # remove one or more
    text = re.sub(r'\v+', '', text) # remove one or more
    text = re.sub(r'\n+', '', text) # remove one or more \n, this is to merge sentences within paragraph

    text = re.sub(r'(\^\*\#)( +)(\#\*\^)', '^*##*^', text) # remove one or more Spaces between Paragraph-Tags or Sentence-Tags

    text = re.sub(r' +', ' ', text) # merge two or more Spaces to 1 Space

    # remove lead & tail spaces:
    text =text.strip()

#     text = re.sub(r'( +)\W', r'\W', text) # remove Spaces before special char
#     text = re.sub(r'\W( +)', r'\W', text) # remove Spaces after special char
    
    return text

# %%
### Define Paragraph-Tag =  
#   #*^P^*#

### Define Sentence-Tag =  
#   #*^S^*#

# %%
# add a special tage to end of each paragraph
def tag_paragraph(text):
    text = re.sub(r'((\n ) +)+', '#*^P^*#', text) # Tag paragraph, pattern: \n + two or more Spaces
    text = re.sub(r'((\n\t) +)+', '#*^P^*#', text) # Tag paragraph, pattern: \n + two or more Tabs
    text = re.sub(r'(\n( *)\n)+', '#*^P^*#', text) # Tag paragraph, pattern: \n + zero or more Spaces + \n
    text = re.sub(r'(\#\*\^P\^\*\#)+', '#*^P^*#', text) # merge two or more Paragraph-Tags -> 1 Paragraph-Tag

    return text

# %%
# add a special tage to end of each sentence
def tag_sentence(text):
    text = re.sub(r'。+', '。#*^S^*#', text) # Tag sentence - Chinese
    text = re.sub(r'！+', '！#*^S^*#', text) # Tag sentence - Chinese
    text = re.sub(r'\？+', '？#*^S^*#', text) # Tag sentence - Chinese
    text = re.sub(r'；+', '；#*^S^*#', text) # Tag sentence - Chinese

    text = re.sub(r'!+', '!#*^S^*#', text) # Tag sentence - English
    text = re.sub(r'\?+', '?#*^S^*#', text) # Tag sentence - English
    text = re.sub(r';+', ';#*^S^*#', text) # Tag sentence - English
   
    # merge two or more sentence-Tags -> 1 Sentence-Tag
    text = re.sub(r'(\W?(\#\*\^S\^\*\#))+', '。#*^S^*#', text)

    # remove a Sentence-Tag immediately before an ending ”
    text = re.sub(r'\#\*\^S\^\*\#”', '”', text) 
    
    # remove a Sentence-Tag immediately before a Paragraph-Tag
    text = re.sub(r'(\#\*\^S\^\*\#)( *)(\#\*\^P\^\*\#)', '#*^P^*#', text) 
    
    text = re.sub(r'(\#\*\^P\^\*\#)+', '#*^P^*#', text) # merge two or more Paragraph-Tags -> 1 Paragraph-Tag

    
    return text

# %% [markdown]
# ### Start tagging:

# %%
content_format = linebreak_conversion_win_linux(content)
# content_format

# %%
content_format = tag_paragraph(content_format)
# content_format

# %%
content_format = clean_some_whitespace(content_format)
# content_format

# %%
content_format = tag_sentence(content_format)
# content_format

# %%
content_format = clean_some_whitespace(content_format)
content_format
# Out:
# '《黄金时代》王小波#*^P^*#一 #*^P^*#我二十一岁时，正在云南插队。#*^S^*#陈清扬当时二十六岁，就在我插队的地方当医生。#*^S^*#我在山下十四队，她在山上十五队。#*^S^*#有一天她从山上下来，和我讨论她不是破鞋的问题。#*^S^*#那时我还不大认识她，只能说有一点知道。#*^S^*#她要讨论的事是这祥的：虽然所有的人都说她是一个破鞋，但她以为自己不是的。#*^S^*#因为破鞋偷汉，而她没有愉过汉。#*^S^*#虽然她丈夫已经住了一年监狱，但她没有偷过汉。#*^S^*#在此之前也未偷过汉。#*^S^*#所以她简直不明白，人们为什么要说她是破鞋。#*^S^*#如果我要安慰她，并不困难。#*^S^*#我可以从逻辑上证明她不是破鞋。#*^S^*#如果陈清扬是破鞋，即陈清扬偷汉，则起码有一个某人为其所偷。#*^S^*#如今不能指出某人，所以陈清扬偷汉不能成立。#*^S^*#但是我偏说，陈清扬就是破鞋，而且这一点毋庸置疑。#*^P^*#陈清扬找我证明她不是破鞋，起因是我找她打针。#*^S^*#这事经过如下：农忙时队长不叫我犁田，而是叫我去插秧，这样我的腰就不能经常直立，认识我的人都知道，我的腰上有旧伤，而且我身高在一米九以上。#*^S^*#如此插了一个月，我腰痛难忍，不打封闭就不能入睡。#*^S^*#我们队医务室那一把针头镀层剥落，而且都有倒钩，经常把我腰上的肉钩下来。#*^S^*#后来我的腰就像中了散弹枪，伤痕久久不褪。#*^S^*#就在这种情况下，我想起十五队的队医陈清扬是北医大毕业的大夫，对针头和勾针大概还能分清，所以我去找她看病，看完病回来，不到半个小时，她就追到我屋里来，要我证明她不是破鞋。#*^P^*#陈清扬说，她丝毫也不藐视破鞋。#*^S^*#据她观察，破鞋都很善良，乐于助人，而且最不乐意让人失望。#*^S^*#因此她对破鞋还有一点钦佩。#*^S^*#问题不在于破鞋好不好，而在于她根本不是破鞋。#*^S^*#就如一只猫不是一只狗一样。#*^S^*#假如一只猫被人叫成一只狗，它也会感到很不自在。#*^S^*#现在大家都管她叫被鞋，弄得她魂不守舍，几乎连自己是谁都不知道了。#*^P^*#陈清扬在我的草房里时，裸臂赤腿穿一件白大褂，和她在山上那间医务室里装束一样，所不同的是披散的长发用个手绢束住，脚上也多了一双拖鞋。#*^S^*#看了她的样子，我就开始捉模：她那件白大褂底下是穿了点什么呢，还是什么都没穿。#*^S^*#这一点可以说明陈清扬很漂亮，因为她觉得穿什么不穿什么无所谓。#*^S^*#这是从小培养起来的自信心。#*^S^*#我对她说，她确实是个破鞋，还举出一些理由来：所谓破鞋者，乃是一个指称，大家都说你是破鞋，你就是破鞋，没什么道理可讲。#*^S^*#大家说你偷了汉，你就是偷了汉，这也没什么道理可讲。#*^S^*#至于大家为什么要说你是破鞋，照我看是这样：大家都认为，结了婚的女人不偷汉，就该面色黝黑，乳房下垂。#*^S^*#而你脸不黑而且白，乳房不下垂而且高耸，所以你是破鞋。#*^S^*#假如你不想当破鞋，就要把脸弄黑，把乳房弄下垂，以后别人就不说你是破鞋。#*^S^*#当然这样很吃亏，假如你不想吃亏，就该去愉个汉来。#*^S^*#这样你自己也认为自己是个破鞋。#*^S^*#别人没有义务先弄明白你是否偷汉再决定是否管你叫破鞋。#*^S^*#你倒有义务叫别人无法叫你破鞋。#*^S^*#陈清扬听了这话，脸色发红，怒目圆睁，几乎就要打我一耳光。#*^S^*#这女人打人耳光出了名，好多人吃过她的耳光。#*^S^*#但是她忽然泄了气，说：好吧，破鞋就破鞋吧。#*^S^*#但是垂不垂黑不黑的，不是你的事，她还说，假如我在这些事上琢磨得太多，很可能会吃耳光。#*^P^*#倒退到二十年前，想像我和陈清扬讨论破鞋问题时的情景。#*^S^*#那时我面色焦黄，嘴唇干裂，上面沾了碎纸和烟丝，头发乱如败棕，身穿一件破军衣，上面好多破洞都是橡皮膏粘上的，跷着二郎腿，坐在木板床上，完全是一副流氓相。#*^S^*#你可以想像陈清扬听到这么个人说起她的乳房下垂不下垂时，手心是何等的发痒。#*^S^*#她有点神经质，都是因为有很多精壮的男人找她看病，其实却没有病。#*^S^*#那些人其实不是去看大夫，而是去看破鞋。#*^S^*#只有我例外。#*^S^*#我的后腰上好像被猪八戒筑了两粑。#*^S^*#不管腰疼真不真，光那些窟窿也能成为看医生的理由。#*^S^*#这些窟窿使她产生一个希望，就是也许能向我证明，她不是破鞋，有一个人承认她不是破鞋，和没人承认大不一样。#*^S^*#可是我偏让她失望。#*^P^*#我是这么想的：假如我想证明她不是破鞋，就能证明她不是破鞋，那事情未免太容易了。#*^S^*#实际上我什么都不能证明，除了那些不需证明的东西。#*^S^*#春天里，队长说我打瞎了他家母狗的左眼，使它老是偏过头来看人，好像在跳芭雷舞，从此后他总给我小鞋穿。#*^S^*#我想证明我自己的清白无辜，只有以下三个途径： #*^P^*#１、队长家不存在一只母狗。#*^S^*#２、该母狗天生没有左眼。#*^S^*#３、我是无手之人，不能持枪射击。#*^P^*#结果是三条一条也不成立。#*^S^*#队长家确有一棕色母狗，该母狗的左眼确是后天打瞎，而我不但能持枪射击，而且枪法极精。#*^S^*#在此之前不久，我还借了罗小四的汽枪，用一碗绿豆做子弹，在空粮库里打下了二斤耗子。#*^S^*#当然，这队里枪法好的人还有不少，其中包括罗小四。#*^S^*#汽枪就是他的，而且他打瞎队长的母狗时，我就在一边看着。#*^S^*#但是我不能揭发别人，罗小四和我也不错。#*^S^*#何况队长要是能惹得起罗小四，也不会认准了是我。#*^S^*#所以我保持沉默。#*^S^*#沉默就是默认。#*^S^*#所以春天我去插秧，撅在地里像一根半截电线杆，秋收后我又去放牛，吃不上热饭。#*^S^*#当然，我也不肯无所作为。#*^S^*#有一天在山上，我正好借了罗小四的汽枪，队长家的母狗正好跑到山上叫我看见，我就射出一颗子弹打瞎了它的右眼。#*^S^*#该狗既无左眼，又无右眼，也就不能跑回去让队长看见——天知道它跑到哪儿去了。#*^P^*#我记得那些日子里，除了上山放牛和在家里躺着，似乎什么也没做。#*^S^*#我觉得什么都与我无关。#*^S^*#可是陈清扬又从山上跑下来找我。#*^S^*#原来又有了另一种传闻，说她在和我搞破鞋。#*^S^*#她要我给出我们清白无辜的证明。#*^S^*#我说，要证明我们无辜，只有证明以下两点： #*^P^*#１、陈清扬是处女。#*^S^*#２、我是天阉之人，没有性交能力。#*^P^*#这两点都难以证明。#*^S^*#所以我们不能证明自己无辜。#*^S^*#我倒倾向于证明自己不无辜。#*^S^*#陈清扬听了这些话，先是气得脸白，然后满面通红，最后一声不吭地站起来走了。#*^P^*#陈清扬说，我始终是一个恶棍。#*^S^*#她第一次要我证明她清白无辜时，我翻了一串白眼，然后开始胡说八道，第二次她要我证明我们俩无辜，我又一本正经地向她建议举行一次性交。#*^S^*#所以她就决定，早晚要打我一个耳光。#*^S^*#假如我知道她有这样的打算，也许后面的事情就不会发生。#*^P^*#二 #*^P^*#我过二十一岁生日那天，正在河边放牛。#*^S^*#下午我躺在草地上睡着了。#*^S^*#我睡去时，身上盖了几片芭蕉叶子，醒来时身上已经一无所有（叶子可能被牛吃了）。#*^S^*#亚热带旱季的阳光把我晒得浑身赤红，痛痒难当，我的小和尚直翘翘地指向天空，尺寸空前。#*^S^*#这就是我过生日时的情形。#*^P^*#我醒来时觉得阳光耀眼，天蓝得吓人，身上落了一层细细的尘土，好像一层爽身粉。#*^S^*#我一生经历的无数次勃起，都不及那一次雄浑有力，大概是因为在极荒僻的地方，四野无人。#*^P^*#我爬起来看牛，发现它们都卧在远处的河岔里静静地嚼草。#*^S^*#那时节万籁无声，田野上刮着白色的风。#*^S^*#河岸上有几对寨子里的牛在斗架，斗得眼珠通红，口角流涎。#*^S^*#这种牛阴囊紧缩，阳具挺直。#*^S^*#我们的牛不干这种事。#*^S^*#任凭别人上门挑衅，我们的牛依旧安卧不动。#*^S^*#为了防止斗架伤身，影响春耕，我们把它们都阉了。#*^P^*#每次阉牛我都在场。#*^S^*#对于一般的公牛，只用刀割去即可。#*^S^*#但是对于格外生性者，就须采取锤骟术，也就是割开阴囊，掏出睾九，一木锤砸个稀烂。#*^S^*#从此后受术者只知道吃草干活，别的什么都不知道，连杀都不用捆。#*^S^*#掌锤的队长毫不怀疑这种手术施之于人类也能得到同等的效力，每回他都对我们呐喊：你们这些生牛蛋子，就欠砸上一锤才能老实。#*^S^*#按他的逻辑，我身上这个通红通红，直不愣登，长约一尺的东西就是罪恶的化身。#*^P^*#当然，我对此有不同的意见，在我看来，这东西无比重要，就如我之存在本身。#*^S^*#天色微微向晚，天上飘着懒洋洋的云彩。#*^S^*#下半截沉在黑暗里，上半截仍浮在阳光中。#*^S^*#那一天我二十一岁，在我一生的黄金时代。#*^S^*#我有好多奢望。#*^S^*#我想爱，想吃，还想在一瞬间变成天上半明半暗的云。#*^S^*#后来我才知道，生活就是个缓慢受锤的过程，人一天天老下去，奢望也一天天消失，最后变得像挨了锤的牛一样。#*^S^*#可是我过二十一岁生日时没有预见到这一点。#*^S^*#我觉得自己会永远生猛下去，什么也锤不了我。#*^S^*#那天晚上我请陈清扬来吃鱼，所以应该在下午把 ...

# %% [markdown]
# ### Transfer tagged text to Pandas Dataframe

# %%
# Split a text into paragraphs
def split_article_to_paragraphs(text):
#     text = text.replace("#*^P^*#", "#*^S^*#") # convert Paragraph-Tag        
    return text.split("#*^P^*#")

# %%
# Split a paragraph into sentences
def split_paragraph_to_sentences(text):
#     text = text.replace("#*^P^*#", "#*^S^*#") # convert Paragraph-Tag        
    return text.split("#*^S^*#")

# %%
# 1st loop Paragraphs list, 2nd loop Sentences list
# create a few new columns, then write into dataframe, together with original Sentence string

# define empty dataframe:
df_article = pd.DataFrame(columns=('sentence', 
                                   'sentence_word_count', 
                                   'sentence_id', 
                                   'sentence_id_paragraph', 'paragraph_id', 'class_rank', 'score'))
df_sentence_id = 0

# split_article_to_paragraphs:
article_paragraphs = split_article_to_paragraphs(content_format)

for i in range(0, len(article_paragraphs)):
    # split_paragraph_to_sentences:
    article_paragraphs_sentences = split_paragraph_to_sentences(article_paragraphs[i].strip())

    for j in range(0, len(article_paragraphs_sentences)):
        if article_paragraphs_sentences[j].strip() != '':
            df_sentence_id = df_sentence_id + 1
            # write to dataframe:
            df_article.loc[len(df_article)] = [article_paragraphs_sentences[j].strip(), 
                                               len(article_paragraphs_sentences[j].strip()), 
                                               df_sentence_id, 
                                               j+1, i+1, '', '']

# %%
# Make sure no empty sentences:
print('Number of empty sentences in dataframe: %d ' % len(df_article[df_article['sentence'] == '']))
# Out:
# Number of empty sentences in dataframe: 0

# %%
df_article
# Out:
#                                                sentence  sentence_word_count  \
# 0                                             《黄金时代》王小波                    9
# 1                                                     一                    1
# 2                                        我二十一岁时，正在云南插队。                   14
# 3                                陈清扬当时二十六岁，就在我插队的地方当医生。                   22
# 4                                      我在山下十四队，她在山上十五队。                   16
# 5                               有一天她从山上下来，和我讨论她不是破鞋的问题。                   23
# 6                                   那时我还不大认识她，只能说有一点知道。                   19
# 7                  她要讨论的事是这祥的：虽然所有的人都说她是一个破鞋，但她以为自己不是的。                   36
# 8                                       因为破鞋偷汉，而她没有愉过汉。                   15
# 9                                虽然她丈夫已经住了一年监狱，但她没有偷过汉。                   22
# 10                                           在此之前也未偷过汉。                   10
# 11                                所以她简直不明白，人们为什么要说她是破鞋。                   21
# 12                                        如果我要安慰她，并不困难。                   13
# 13                                      我可以从逻辑上证明她不是破鞋。                   15
# 14                        如果陈清扬是破鞋，即陈清扬偷汉，则起码有一个某人为其所偷。                   29
# 15                                如今不能指出某人，所以陈清扬偷汉不能成立。                   21
# 16                             但是我偏说，陈清扬就是破鞋，而且这一点毋庸置疑。                   24
# 17                               陈清扬找我证明她不是破鞋，起因是我找她打针。                   22
# 18    这事经过如下：农忙时队长不叫我犁田，而是叫我去插秧，这样我的腰就不能经常直立，认识我的人都知...                   68
# 19                             如此插了一个月，我腰痛难忍，不打封闭就不能入睡。                   24
# 20                  我们队医务室那一把针头镀层剥落，而且都有倒钩，经常把我腰上的肉钩下来。                   35
# 21                                 后来我的腰就像中了散弹枪，伤痕久久不褪。                   20
# 22    就在这种情况下，我想起十五队的队医陈清扬是北医大毕业的大夫，对针头和勾针大概还能分清，所以我...                   84
# 23                                      陈清扬说，她丝毫也不藐视破鞋。                   15
# 24                         据她观察，破鞋都很善良，乐于助人，而且最不乐意让人失望。                   28
# 25                                        因此她对破鞋还有一点钦佩。                   13
# 26                               问题不在于破鞋好不好，而在于她根本不是破鞋。                   22
# 27                                        就如一只猫不是一只狗一样。                   13
# 28                              假如一只猫被人叫成一只狗，它也会感到很不自在。                   23
# 29                     现在大家都管她叫被鞋，弄得她魂不守舍，几乎连自己是谁都不知道了。                   32
# ...                                                 ...                  ...
# 1426                              从内衣到外衣，她都是一个香喷喷的ＬＡＤＹ。                   21
# 1427  而我从谝碌酵庖露际且桓龅氐赖耐亮髅ィ薰秩思野阉慕淮牧铣榱顺隼矗豢铣槌鑫业摹Ｕ饩褪撬担...                  117
# 1428                                       我们结了账，走到街上去。                   12
# 1429                                这时我想，她那篇交待材料一定淫秽万分。                   19
# 1430               看交待材料的人都心硬如铁，水平无比之高，能叫人家看了受不住，那还好得了。                   36
# 1431                          陈清扬说，那篇材料里什么也没写，只有她真实的罪孽。                   25
# 1432                                陈清扬说她真实的罪孽，是指在清平山上。                   19
# 1433               那时她被架在我的肩上，穿着紧裹住双腿的筒裙，头发低垂下去，直到我的腰际。                   36
# 1434                                 天上白云匆匆，深山里只有我们两个人。                   18
# 1435                    我刚在她屁股上打了两下，打得非常之重，火烧火撩的感觉正在飘散。                   31
# 1436                               打过之后我就不管别的事，继续往山上攀登。                   20
# 1437                       陈清扬说，那一刻她感到浑身无力，就瘫软下来，挂在我肩上。                   28
# 1438         那一刻她觉得如春藤绕树，小鸟依人，她再也不想理会别的事，而且在那一瞬间把一切部遗忘。                   42
# 1439                            在那一瞬间她爱上了我，而且这件事永远不能改变。                   23
# 1440                          在车站上陈清扬说，这篇材料交上去，团长拿起来就看。                   25
# 1441                                   看完了面红耳赤，就像你的小和尚。                   16
# 1442                      后来见过她这篇交待材料的人，一个个都面红耳赤，好像小和尚。                   29
# 1443         后来人保组的人找了她好几回，让她拿回去重写，但是她说，这是真实情况，一个字都不能改。                   42
# 1444                                人家只好把这个东西放进了我们的档案袋。                   19
# 1445                             陈清扬说，承认了这个，就等于承认了一切罪孽。                   22
# 1446              在人保组里，人家把各种交待材料拿给她看，就是想让她明白，谁也不这么写交待。                   37
# 1447                                          但是她偏要这么写。                    9
# 1448                   她说，她之所以要把这事最后写出来，是因为它比她干过的一切事都坏。                   32
# 1449                      以前她承认过分开双腿，现在又加上，她做这些事是因为她喜欢。                   29
# 1450                                     做过这事和喜欢这事大不一样。                   14
# 1451                             前者该当出斗争差，后者就该五马分尸千刀万剐。                   22
# 1452                          但是谁也没权力把我们五马分尸，所以只好把我们放了。                   25
# 1453                                陈清扬告诉我这件事以后，火车就开走了。                   19
# 1454                                         以后我再也没见过她。                   10
# 1455                                              （全文完）                    5
#
#       sentence_id  sentence_id_paragraph  paragraph_id class_rank score
# 0               1                      1             1
# 1               2                      1             2
# 2               3                      1             3
# 3               4                      2             3
# 4               5                      3             3
# 5               6                      4             3
# 6               7                      5             3
# 7               8                      6             3
# 8               9                      7             3
# 9              10                      8             3
# 10             11                      9             3
# 11             12                     10             3
# 12             13                     11             3
# 13             14                     12             3
# 14             15                     13             3
# 15             16                     14             3
# 16             17                     15             3
# 17             18                      1             4
# 18             19                      2             4
# 19             20                      3             4
# 20             21                      4             4
# 21             22                      5             4
# 22             23                      6             4
# 23             24                      1             5
# 24             25                      2             5
# 25             26                      3             5
# 26             27                      4             5
# 27             28                      5             5
# 28             29                      6             5
# 29             30                      7             5
# ...           ...                    ...           ...        ...   ...
# 1426         1427                      3           206
# 1427         1428                      4           206
# 1428         1429                      1           207
# 1429         1430                      2           207
# 1430         1431                      3           207
# 1431         1432                      4           207
# 1432         1433                      1           208
# 1433         1434                      2           208
# 1434         1435                      3           208
# 1435         1436                      4           208
# 1436         1437                      5           208
# 1437         1438                      1           209
# 1438         1439                      2           209
# 1439         1440                      3           209
# 1440         1441                      1           210
# 1441         1442                      2           210
# 1442         1443                      3           210
# 1443         1444                      4           210
# 1444         1445                      5           210
# 1445         1446                      1           211
# 1446         1447                      2           211
# 1447         1448                      3           211
# 1448         1449                      4           211
# 1449         1450                      5           211
# 1450         1451                      6           211
# 1451         1452                      7           211
# 1452         1453                      8           211
# 1453         1454                      1           212
# 1454         1455                      2           212
# 1455         1456                      1           213
#
# [1456 rows x 7 columns]

# %% [markdown]
# ### Calculate importance score for each sentence

# %% [markdown]
# ### [Optional Reference] word_tokenizer

# %%
# KudosData_word_tokenizer
df_article['sentence_tokenized'] = df_article['sentence'].apply(lambda x: KudosData_word_tokenizer(x))
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\TELESC~1\AppData\Local\Temp\jieba.cache
# DEBUG:jieba:Loading model from cache C:\Users\TELESC~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.768 seconds.
# DEBUG:jieba:Loading model cost 1.768 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %% [markdown]
# ### [Optional Reference] Term Frequency

# %%
# KudosData_word_count
df_article['sentence_tf'] = df_article['sentence'].apply(lambda x: KudosData_word_count(x))

# %% [markdown]
# ### [Optional Reference] TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = df_article['sentence_tokenized']

vectorizer = TfidfVectorizer()

# my_stopword_list = ['and','to','the','of', 'in']
#vectorizer = TfidfVectorizer(stop_words=my_stopword_list)

# choice of no nomalization of tfidf output (not recommended)
#vectorizer = TfidfVectorizer(norm=None)

# TF-IDF score
tfidf = vectorizer.fit_transform(corpus)

# IDF score
idf_dict = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))

# TF is in df_article[['sentence_tf']]

# %%
### 把TF-iDF数值赋予相对应的词组
tfidf = tfidf.tocsr()

n_docs = tfidf.shape[0]
tfidftables = [{} for _ in range(n_docs)]
terms = vectorizer.get_feature_names()

for i, j in zip(*tfidf.nonzero()):
    tfidftables[i][terms[j]] = tfidf[i, j]

# %%
# Document-Term-Matrix's TF-IDF matrix size:
print ('This tfidf matrix is a very large table: [ %d rows/docs X %d columns/words ]' 
       % (tfidf.shape[0], tfidf.shape[1]))
print ('It contains %d eliments: one score per word per document !'
       % (tfidf.shape[0] * tfidf.shape[1]))
# Out:
# This tfidf matrix is a very large table: [ 1456 rows/docs X 3955 columns/words ]
# It contains 5758480 eliments: one score per word per document !

# %%
# Add tfidf score into dataframe 
df_article['tfidf'] = tfidftables

# %%
# df_article[['sentence', 'sentence_tokenized', 'tfidf']].head()
df_article[['sentence', 'sentence_tokenized', 'sentence_tf', 'tfidf']]
# Out:
#                                                sentence  \
# 0                                             《黄金时代》王小波
# 1                                                     一
# 2                                        我二十一岁时，正在云南插队。
# 3                                陈清扬当时二十六岁，就在我插队的地方当医生。
# 4                                      我在山下十四队，她在山上十五队。
# 5                               有一天她从山上下来，和我讨论她不是破鞋的问题。
# 6                                   那时我还不大认识她，只能说有一点知道。
# 7                  她要讨论的事是这祥的：虽然所有的人都说她是一个破鞋，但她以为自己不是的。
# 8                                       因为破鞋偷汉，而她没有愉过汉。
# 9                                虽然她丈夫已经住了一年监狱，但她没有偷过汉。
# 10                                           在此之前也未偷过汉。
# 11                                所以她简直不明白，人们为什么要说她是破鞋。
# 12                                        如果我要安慰她，并不困难。
# 13                                      我可以从逻辑上证明她不是破鞋。
# 14                        如果陈清扬是破鞋，即陈清扬偷汉，则起码有一个某人为其所偷。
# 15                                如今不能指出某人，所以陈清扬偷汉不能成立。
# 16                             但是我偏说，陈清扬就是破鞋，而且这一点毋庸置疑。
# 17                               陈清扬找我证明她不是破鞋，起因是我找她打针。
# 18    这事经过如下：农忙时队长不叫我犁田，而是叫我去插秧，这样我的腰就不能经常直立，认识我的人都知...
# 19                             如此插了一个月，我腰痛难忍，不打封闭就不能入睡。
# 20                  我们队医务室那一把针头镀层剥落，而且都有倒钩，经常把我腰上的肉钩下来。
# 21                                 后来我的腰就像中了散弹枪，伤痕久久不褪。
# 22    就在这种情况下，我想起十五队的队医陈清扬是北医大毕业的大夫，对针头和勾针大概还能分清，所以我...
# 23                                      陈清扬说，她丝毫也不藐视破鞋。
# 24                         据她观察，破鞋都很善良，乐于助人，而且最不乐意让人失望。
# 25                                        因此她对破鞋还有一点钦佩。
# 26                               问题不在于破鞋好不好，而在于她根本不是破鞋。
# 27                                        就如一只猫不是一只狗一样。
# 28                              假如一只猫被人叫成一只狗，它也会感到很不自在。
# 29                     现在大家都管她叫被鞋，弄得她魂不守舍，几乎连自己是谁都不知道了。
# ...                                                 ...
# 1426                              从内衣到外衣，她都是一个香喷喷的ＬＡＤＹ。
# 1427  而我从谝碌酵庖露际且桓龅氐赖耐亮髅ィ薰秩思野阉慕淮牧铣榱顺隼矗豢铣槌鑫业摹Ｕ饩褪撬担...
# 1428                                       我们结了账，走到街上去。
# 1429                                这时我想，她那篇交待材料一定淫秽万分。
# 1430               看交待材料的人都心硬如铁，水平无比之高，能叫人家看了受不住，那还好得了。
# 1431                          陈清扬说，那篇材料里什么也没写，只有她真实的罪孽。
# 1432                                陈清扬说她真实的罪孽，是指在清平山上。
# 1433               那时她被架在我的肩上，穿着紧裹住双腿的筒裙，头发低垂下去，直到我的腰际。
# 1434                                 天上白云匆匆，深山里只有我们两个人。
# 1435                    我刚在她屁股上打了两下，打得非常之重，火烧火撩的感觉正在飘散。
# 1436                               打过之后我就不管别的事，继续往山上攀登。
# 1437                       陈清扬说，那一刻她感到浑身无力，就瘫软下来，挂在我肩上。
# 1438         那一刻她觉得如春藤绕树，小鸟依人，她再也不想理会别的事，而且在那一瞬间把一切部遗忘。
# 1439                            在那一瞬间她爱上了我，而且这件事永远不能改变。
# 1440                          在车站上陈清扬说，这篇材料交上去，团长拿起来就看。
# 1441                                   看完了面红耳赤，就像你的小和尚。
# 1442                      后来见过她这篇交待材料的人，一个个都面红耳赤，好像小和尚。
# 1443         后来人保组的人找了她好几回，让她拿回去重写，但是她说，这是真实情况，一个字都不能改。
# 1444                                人家只好把这个东西放进了我们的档案袋。
# 1445                             陈清扬说，承认了这个，就等于承认了一切罪孽。
# 1446              在人保组里，人家把各种交待材料拿给她看，就是想让她明白，谁也不这么写交待。
# 1447                                          但是她偏要这么写。
# 1448                   她说，她之所以要把这事最后写出来，是因为它比她干过的一切事都坏。
# 1449                      以前她承认过分开双腿，现在又加上，她做这些事是因为她喜欢。
# 1450                                     做过这事和喜欢这事大不一样。
# 1451                             前者该当出斗争差，后者就该五马分尸千刀万剐。
# 1452                          但是谁也没权力把我们五马分尸，所以只好把我们放了。
# 1453                                陈清扬告诉我这件事以后，火车就开走了。
# 1454                                         以后我再也没见过她。
# 1455                                              （全文完）
#
#                                      sentence_tokenized  \
# 0                                   黄金 黄金时代 时代   王小波 小波
# 1                                                     一
# 2                  我 二十 二十一 二十一岁 十一 十一岁 一岁 时   正在 云南 插队
# 3     陈 清扬 当时 二十 二十六 二十六岁 十六 十六岁 六岁   就 在 我 插队 的 地方 ...
# 4                           我 在 山下 十四 四队   她 在 山上 十五 五队
# 5               有 一天 她 从 山上 上下 下来   和 我 讨论 她 不是 破鞋 的 问题
# 6                         那时 我 还 不大 认识 她   只能 说 有 一点 知道
# 7     她 要 讨论 的 事 是 这 祥 的   虽然 所有 的 人 都 说 她 是 一个 破鞋  ...
# 8                              因为 破鞋 偷 汉   而 她 没有 愉 过 汉
# 9                   虽然 她 丈夫 已经 住 了 一年 监狱   但 她 没有 偷 过 汉
# 10                                    在此之前 之前 也 未 偷 过 汉
# 11                  所以 她 简直 不明 明白   人们 为什么 什么 要说 她 是 破鞋
# 12                                 如果 我 要 安慰 她   并 不 困难
# 13                              我 可以 从 逻辑 上证 证明 她 不是 破鞋
# 14    如果 陈 清扬 是 破鞋   即 陈 清扬 偷 汉   则 起码 有 一个 某人 人为 其 所 偷
# 15                如今 不能 能指 指出 某人   所以 陈 清扬 偷 汉 不能 能成 成立
# 16           但是 我 偏 说   陈 清扬 就是 破鞋   而且 这 一点 毋庸 毋庸置疑 置疑
# 17                  陈 清扬 找 我 证明 她 不是 破鞋   起因 是 我 找 她 打针
# 18    这事 经过 如下   农忙 时 队长 不 叫 我 犁田   而是 叫 我 去 插秧   这样...
# 19             如此 插 了 一个 一个月   我 腰痛 难忍   不 打 封闭 就 不能 入睡
# 20    我们 队医 医务 医务室 那 一把 针头 镀层 剥落   而且 都 有 倒钩   经常 把 ...
# 21                  后来 我 的 腰 就 像 中 了 散弹 散弹枪   伤痕 久久 不 褪
# 22    就 在 这种 情况 下   我 想起 十五 五队 的 队医 陈 清扬 是 北医 北医大 医大...
# 23                              陈 清扬 说   她 丝毫 也 不 藐视 破鞋
# 24    据 她 观察   破鞋 都 很 善良   乐于 乐于助人 助人   而且 最 不乐 不乐意 ...
# 25                                   因此 她 对 破鞋 还有 一点 钦佩
# 26                 问题 不在 在于 破鞋 好不好 不好   而 在于 她 根本 不是 破鞋
# 27                                 就 如一 一只 猫 不是 一只 狗 一样
# 28       假如 如一 一只 猫 被 人 叫 成 一只 狗   它 也 会 感到 很 不自 不自在 自在
# 29    现在 大家 都 管 她 叫 被 鞋   弄 得 她 魂不守舍 不守 舍   几乎 连 自己 ...
# ...                                                 ...
# 1426                      从 内衣 到 外衣   她 都 是 一个 香喷喷 喷喷 的
# 1427  而 我 从 谝 碌 酵 庖 露 际 且 桓 龅 氐 赖 耐 亮 髅    薰 秩 思 野 阉...
# 1428                                我们 结 了 账   走到 街上 上去
# 1429                      这时 我 想   她 那 篇 交待 材料 一定 淫秽 万分
# 1430  看 交待 材料 的 人 都 心硬 如 铁   水平 无比 之 高   能 叫 人家 看 了 ...
# 1431           陈 清扬 说   那 篇 材料 里 什么 也 没写   只有 她 真实 的 罪孽
# 1432                  陈 清扬 说 她 真实 的 罪孽   是 指 在 清平 平山 山上
# 1433  那时 她 被 架 在 我 的 肩上   穿着 着紧 裹住 双腿 的 筒裙   头发 低垂 垂...
# 1434                       天上 白云 匆匆   深山 山里 只有 我们 两个 个人
# 1435  我 刚在 她 屁股 上 打 了 两下   打得 非常 之 重   火烧 烧火 撩 的 感觉 ...
# 1436                     打过 之后 我 就 不管 别的 事   继续 往 山上 攀登
# 1437    陈 清扬 说   那一刻 一刻 她 感到 浑身 无力   就 瘫软 下来   挂 在 我 肩上
# 1438  那一刻 一刻 她 觉得 如春 藤 绕 树   小鸟 小鸟依人 依人   她 再也 不想 理会...
# 1439         在 那 一瞬 一瞬间 瞬间 她 爱 上 了 我   而且 这件 事 永远 不能 改变
# 1440   在 车站 站上 陈 清扬 说   这 篇 材料 交上 交上去 上去   团长 拿起 起来 就 看
# 1441                        看完 了 面红 面红耳赤   就 像 你 的 小 和尚
# 1442  后来 来见 过 她 这 篇 交待 材料 的 人   一个 一个个 个个 都 面红 面红耳赤 ...
# 1443  后来 人 保 组 的 人 找 了 她 好几 好几回 几回   让 她 拿回去 回去 重写  ...
# 1444                     人家 只好 把 这个 东西 放进 了 我们 的 档案 档案袋
# 1445                 陈 清扬 说   承认 了 这个   就 等于 承认 了 一切 罪孽
# 1446  在 人 保 组里   人家 把 各种 交待 材料 拿给 她 看   就是 想 让 她 明白 ...
# 1447                                       但是 她 偏要 这么 写
# 1448  她 说   她 之所以 所以 要 把 这事 最后 后写 写出 出来   是因为 因为 它 比...
# 1449  以前 她 承认 认过 过分 分开 双腿   现在 又 加上   她 做 这些 事 是因为 因...
# 1450                          做 过 这事 和 喜欢 这事 大不一样 不一 一样
# 1451       前者 该当 出 斗争 差   后者 就 该 五马 五马分尸 马分尸 分尸 千刀 千刀万剐
# 1452  但是 谁 也 没权 权力 把 我们 五马 五马分尸 马分尸 分尸   所以 只好 把 我们 放 了
# 1453                      陈 清扬 告诉 我 这件 事 以后   火车 就 开走 了
# 1454                                     以后 我 再也 没见 过 她
# 1455                                             全文 全文完
#
#                                             sentence_tf  \
# 0      {'王小波': 1, '黄金时代': 1, '小波': 1, '时代': 1, '黄金': 1}
# 1                                              {'一': 1}
# 2     {'十一岁': 1, '云南': 1, '十一': 1, '二十一岁': 1, '二十': ...
# 3     {'的': 1, '就': 1, '插队': 1, '地方': 1, '医生': 1, '清...
# 4     {'十四': 1, '四队': 1, '山上': 1, '十五': 1, '她': 1, '...
# 5     {'的': 1, '山上': 1, '破鞋': 1, '她': 2, '下来': 1, '上...
# 6     {'一点': 1, '她': 1, '那时': 1, '有': 1, '我': 1, '还'...
# 7     {'以为': 1, '要': 1, '破鞋': 1, '但': 1, '她': 3, '事'...
# 8     {'而': 1, '过': 1, '破鞋': 1, '没有': 1, '她': 1, '因为...
# 9     {'已经': 1, '但': 1, '她': 2, '了': 1, '偷': 1, '监狱'...
# 10    {'之前': 1, '汉': 1, '也': 1, '在此之前': 1, '未': 1, '...
# 11    {'人们': 1, '破鞋': 1, '她': 2, '明白': 1, '是': 1, '所...
# 12    {'并': 1, '安慰': 1, '不': 1, '要': 1, '我': 1, '她':...
# 13    {'证明': 1, '上证': 1, '逻辑': 1, '我': 1, '破鞋': 1, '...
# 14    {'如果': 1, '所': 1, '则': 1, '破鞋': 1, '某人': 1, '即...
# 15    {'不能': 2, '如今': 1, '某人': 1, '偷': 1, '清扬': 1, '...
# 16    {'置疑': 1, '破鞋': 1, '一点': 1, '毋庸': 1, '就是': 1, ...
# 17    {'她': 2, '破鞋': 1, '找': 2, '起因': 1, '不是': 1, '清...
# 18    {'犁田': 1, '九': 1, '的': 3, '旧伤': 1, '腰': 2, '人'...
# 19    {'不能': 1, '如此': 1, '入睡': 1, '就': 1, '了': 1, '难...
# 20    {'钩下来': 1, '的': 1, '医务': 1, '针头': 1, '医务室': 1,...
# 21    {'散弹': 1, '像': 1, '中': 1, '腰': 1, '了': 1, '就':...
# 22    {'的': 2, '针头': 1, '半个': 1, '看完': 1, '里来': 1, '...
# 23    {'丝毫': 1, '也': 1, '不': 1, '陈': 1, '破鞋': 1, '说'...
# 24    {'最': 1, '乐于助人': 1, '不乐': 1, '破鞋': 1, '乐意': 1,...
# 25    {'对': 1, '因此': 1, '一点': 1, '破鞋': 1, '她': 1, '钦...
# 26    {'而': 1, '不好': 1, '不在': 1, '不是': 1, '破鞋': 2, '...
# 27    {'如一': 1, '就': 1, '一只': 2, '猫': 1, '狗': 1, '不是...
# 28    {'不自': 1, '人': 1, '很': 1, '假如': 1, '猫': 1, '感到...
# 29    {'不守': 1, '连': 1, '不知': 1, '弄': 1, '自己': 1, '是...
# ...                                                 ...
# 1426  {'外衣': 1, '的': 1, '她': 1, '香喷喷': 1, '到': 1, '是...
# 1427  {'鸱': 1, '亮': 1, '兀': 1, '褪': 1, '慕': 1, '瞧': ...
# 1428  {'结': 1, '账': 1, '走到': 1, '街上': 1, '上去': 1, '了...
# 1429  {'淫秽': 1, '材料': 1, '万分': 1, '她': 1, '交待': 1, '...
# 1430  {'如': 1, '的': 1, '高': 1, '人': 1, '都': 1, '叫': ...
# 1431  {'没写': 1, '的': 1, '陈': 1, '她': 1, '材料': 1, '罪孽...
# 1432  {'清平': 1, '的': 1, '山上': 1, '是': 1, '她': 1, '罪孽...
# 1433  {'垂下': 1, '腰际': 1, '架': 1, '的': 3, '在': 1, '着紧...
# 1434  {'山里': 1, '白云': 1, '天上': 1, '深山': 1, '只有': 1, ...
# 1435  {'烧火': 1, '的': 1, '打': 1, '刚在': 1, '感觉': 1, '她...
# 1436  {'不管': 1, '山上': 1, '就': 1, '事': 1, '之后': 1, '攀...
# 1437  {'瘫软': 1, '浑身': 1, '就': 1, '她': 1, '下来': 1, '清...
# 1438  {'觉得': 1, '一瞬间': 1, '树': 1, '一瞬': 1, '绕': 1, '...
# 1439  {'一瞬': 1, '一瞬间': 1, '她': 1, '这件': 1, '事': 1, '...
# 1440  {'车站': 1, '拿起': 1, '交上': 1, '材料': 1, '站上': 1, ...
# 1441  {'看完': 1, '的': 1, '像': 1, '就': 1, '你': 1, '了':...
# 1442  {'的': 1, '她': 1, '人': 1, '后来': 1, '来见': 1, '交待...
# 1443  {'让': 1, '的': 1, '改': 1, '是': 1, '人': 2, '字': ...
# 1444  {'把': 1, '人家': 1, '的': 1, '档案袋': 1, '只好': 1, '...
# 1445  {'承认': 2, '一切': 1, '这个': 1, '陈': 1, '就': 1, '了...
# 1446  {'想': 1, '就是': 1, '人': 1, '写': 1, '让': 1, '保':...
# 1447        {'这么': 1, '偏要': 1, '写': 1, '她': 1, '但是': 1}
# 1448  {'比': 1, '坏': 1, '之所以': 1, '的': 1, '切事': 1, '要...
# 1449  {'承认': 1, '这些': 1, '认过': 1, '是因为': 1, '她': 3, ...
# 1450  {'不一': 1, '过': 1, '做': 1, '大不一样': 1, '这事': 2, ...
# 1451  {'五马分尸': 1, '差': 1, '五马': 1, '分尸': 1, '就': 1, ...
# 1452  {'把': 2, '马分尸': 1, '分尸': 1, '五马分尸': 1, '只好': 1...
# 1453  {'告诉': 1, '就': 1, '这件': 1, '事': 1, '了': 1, '清扬...
# 1454  {'以后': 1, '我': 1, '她': 1, '再也': 1, '没见': 1, '过...
# 1455                                {'全文': 1, '全文完': 1}
#
#                                                   tfidf
# 0     {'黄金': 0.417605484371, '时代': 0.417605484371, '...
# 1                                                    {}
# 2     {'一岁': 0.334452413499, '十一岁': 0.334452413499, ...
# 3     {'二十六': 0.346726964056, '十六岁': 0.346726964056,...
# 4     {'十四': 0.461899610352, '四队': 0.461899610352, '...
# 5     {'上下': 0.424145930069, '一天': 0.407328288271, '...
# 6     {'一点': 0.354980862442, '不大': 0.428789491976, '...
# 7     {'以为': 0.387291263007, '自己': 0.308576860009, '...
# 8     {'因为': 0.599879892089, '破鞋': 0.559203184229, '...
# 9     {'监狱': 0.472081018283, '虽然': 0.358119614565, '...
# 10       {'之前': 0.680849352232, '在此之前': 0.732423483761}
# 11    {'破鞋': 0.229225004872, '所以': 0.236458782864, '...
# 12    {'如果': 0.500403866644, '安慰': 0.61220746902, '困...
# 13    {'证明': 0.365034745999, '上证': 0.547054800163, '...
# 14    {'如果': 0.378409995268, '起码': 0.438228519273, '...
# 15    {'能指': 0.367043784437, '能成': 0.333528334687, '...
# 16    {'清扬': 0.176826772733, '破鞋': 0.243295036134, '...
# 17    {'证明': 0.392862764018, '破鞋': 0.317568906379, '...
# 18    {'以上': 0.26565572078, '旧伤': 0.241398203453, '认...
# 19    {'不能': 0.250524601248, '如此': 0.306597508022, '...
# 20    {'钩下来': 0.307438907761, '一把': 0.246522998678, ...
# 21    {'伤痕': 0.482989712754, '散弹枪': 0.482989712754, ...
# 22    {'北医': 0.221610908842, '不是': 0.126494203283, '...
# 23    {'丝毫': 0.590437913976, '藐视': 0.671492199577, '...
# 24    {'乐于': 0.323329047595, '助人': 0.341573879049, '...
# 25    {'因此': 0.48169361506, '钦佩': 0.589316847003, '一...
# 26    {'不好': 0.268655161261, '不在': 0.291598369444, '...
# 27    {'一只': 0.784235139194, '如一': 0.462889958932, '...
# 28    {'感到': 0.277395956179, '如一': 0.348517268283, '...
# 29    {'不守': 0.447243173006, '现在': 0.303345818465, '...
# ...                                                 ...
# 1426  {'香喷喷': 0.494350878201, '外衣': 0.467945614201, ...
# 1427                                                 {}
# 1428  {'上去': 0.47794845299, '走到': 0.544830533726, '我...
# 1429  {'淫秽': 0.52074910407, '材料': 0.302731532911, '这...
# 1430  {'人家': 0.26695017963, '材料': 0.250612579818, '无...
# 1431  {'没写': 0.504558671151, '材料': 0.309870855766, '...
# 1432  {'清平': 0.422069432857, '山上': 0.29924128452, '平...
# 1433  {'腰际': 0.302783395323, '垂下去': 0.302783395323, ...
# 1434  {'山里': 0.308689449792, '天上': 0.348358827159, '...
# 1435  {'飘散': 0.358305328657, '烧火': 0.325587803535, '...
# 1436  {'山上': 0.249828044018, '不管': 0.337936851756, '...
# 1437  {'瘫软': 0.404723126413, '无力': 0.404723126413, '...
# 1438  {'小鸟': 0.26736361659, '如春': 0.26736361659, '瞬间...
# 1439  {'一瞬': 0.37471995342, '一瞬间': 0.37471995342, '改...
# 1440  {'车站': 0.369201309302, '拿起': 0.39003462357, '交...
# 1441  {'看完': 0.515056844595, '和尚': 0.398711293146, '...
# 1442  {'一个': 0.210552853841, '和尚': 0.270456598778, '...
# 1443  {'一个': 0.17420622376, '不能': 0.195839159335, '实...
# 1444  {'人家': 0.27945994045, '档案袋': 0.427192042776, '...
# 1445  {'一切': 0.28973740874, '承认': 0.709828166779, '罪...
# 1446  {'人家': 0.257985534549, '拿给': 0.394365529934, '...
# 1447  {'偏要': 0.74132362281, '这么': 0.526746210209, '但...
# 1448  {'一切': 0.25628697538, '这事': 0.297826139185, '最...
# 1449  {'承认': 0.28931635038, '这些': 0.232597502107, '认...
# 1450  {'这事': 0.691803892623, '不一': 0.364615721852, '...
# 1451  {'五马分尸': 0.314472879376, '后者': 0.332217974422,...
# 1452  {'但是': 0.201525183868, '五马分尸': 0.340018194698,...
# 1453  {'以后': 0.353737543169, '告诉': 0.373667495319, '...
# 1454  {'再也': 0.641963816041, '没见': 0.616261929979, '...
# 1455      {'全文': 0.707106781187, '全文完': 0.707106781187}
#
# [1456 rows x 4 columns]

# %% [markdown]
# ### Calculate score for each sentence, based on pair-wise sentence comparison/intersection:

# %%
# experiment: use tf-idf and len(sentence) to calculate score
# tmp_mean = tmp_sum / len(df_article['sentence'][i])

# for i in range(0,len(df_article)):
#     if len(df_article['tfidf'][i]) == 0:
#         df_article['score'][i] = 0
#     else:
#         tmp_sum = 0
#         for key, values in df_article['tfidf'][i].items():
#             tmp_sum += values
        
#         tmp_mean = tmp_sum / len(df_article['sentence_tokenized'][i])
#         df_article['score'][i] = tmp_mean

# %% [markdown]
# ### Experiment:
# ### Calculate score for each sentence, based on pair-wise sentence comparison/intersection:

# %%
# Caculate raw intersection score between pair of two sentences, from df_article['sentence_tokenized']
def sentences_intersection(sent1tokenized, sent2tokenized):
    # www.KudosData.com - Chinese
    # split the sentence into words/tokens
    s1 = set(sent1tokenized.split(" "))
    s2 = set(sent2tokenized.split(" "))

    # If there is not intersection, just return 0
    if (len(s1) + len(s2)) == 0:
        print('# If there is not intersection, just return 0')
        return 0

    # Normalize the result by the average number of words
    return len(s1.intersection(s2)) / ((len(s1) + len(s2)) / 2)

# %%
# Calculate important score of every pair of sentences

n = len(df_article['sentence_tokenized'])
        
# [Sam python 2.7 -> 3.4] values = [[0 for x in xrange(n)] for x in xrange(n)]
df_score_raw_values = [[0 for x in range(n)] for x in range(n)]
for i in range(0, n):
    for j in range(0, n):
        df_score_raw_values[i][j] = sentences_intersection(df_article['sentence_tokenized'][i], 
                                                           df_article['sentence_tokenized'][j])

# The score of a sentence is the sum of all its intersection
sentences_dic = {}

for i in range(0, n):
    df_score = 0
    for j in range(0, n):
        if i == j:
            continue
        df_score += df_score_raw_values[i][j]
    df_article['score'][i] = df_score
# Out:
# G:\Tool_PGM\Anaconda3\lib\site-packages\ipykernel\__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_article.head()
# Out:
#                  sentence  sentence_word_count  sentence_id  \
# 0               《黄金时代》王小波                    9            1
# 1                       一                    1            2
# 2          我二十一岁时，正在云南插队。                   14            3
# 3  陈清扬当时二十六岁，就在我插队的地方当医生。                   22            4
# 4        我在山下十四队，她在山上十五队。                   16            5
#
#    sentence_id_paragraph  paragraph_id class_rank    score  \
# 0                      1             1              107.43
# 1                      1             2             4.30814
# 2                      1             3             145.021
# 3                      2             3             192.697
# 4                      3             3             207.951
#
#                                   sentence_tokenized  \
# 0                                黄金 黄金时代 时代   王小波 小波
# 1                                                  一
# 2               我 二十 二十一 二十一岁 十一 十一岁 一岁 时   正在 云南 插队
# 3  陈 清扬 当时 二十 二十六 二十六岁 十六 十六岁 六岁   就 在 我 插队 的 地方 ...
# 4                        我 在 山下 十四 四队   她 在 山上 十五 五队
#
#                                          sentence_tf  \
# 0   {'王小波': 1, '黄金时代': 1, '小波': 1, '时代': 1, '黄金': 1}
# 1                                           {'一': 1}
# 2  {'十一岁': 1, '云南': 1, '十一': 1, '二十一岁': 1, '二十': ...
# 3  {'的': 1, '就': 1, '插队': 1, '地方': 1, '医生': 1, '清...
# 4  {'十四': 1, '四队': 1, '山上': 1, '十五': 1, '她': 1, '...
#
#                                                tfidf
# 0  {'黄金': 0.417605484371, '时代': 0.417605484371, '...
# 1                                                 {}
# 2  {'一岁': 0.334452413499, '十一岁': 0.334452413499, ...
# 3  {'二十六': 0.346726964056, '十六岁': 0.346726964056,...
# 4  {'十四': 0.461899610352, '四队': 0.461899610352, '...

# %% [markdown]
# ### Generate class_rank

# %%
# sort firstly
df_article = df_article.sort_values(by=['paragraph_id', 'score'], ascending=[True, False]).reset_index(drop=True)

# %%
# df_article.head()

# %%
# Generate Class_Rank

current_class_rank = 0
current_paragraph_id = 0

for i in range(0, len(df_article)):
    if df_article['paragraph_id'][i] != current_paragraph_id: # change of Paragraph, thus reset class_rank
        current_class_rank = 1
        current_paragraph_id = df_article['paragraph_id'][i]
    else:
        current_class_rank = current_class_rank + 1
        
    df_article['class_rank'][i] = current_class_rank
# Out:
# G:\Tool_PGM\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# sort Dataframe to 'result lookup mode'
df_article = df_article.sort_values(by=['class_rank', 'score', 'paragraph_id', 'sentence_id'], 
                                    ascending=[True, False, True, True]).reset_index(drop=True)

# Display only
# df_article.sort_values(by=['class_rank', 'score', 'paragraph_id', 'sentence_id'], 
#                        ascending=[True, False, True, True])

# %% [markdown]
# ### Extract results based on user parameters
# Max number of words
#
# % of original number of words, etc

# %%
parm_max_word = 200
parm_max_percent = 0.15

# %%
df_article_display = df_article[0:30]

# %%
df_article_display = df_article_display.sort_values(by=['sentence_id'], ascending=[True]).reset_index(drop=True)
df_article_display[['sentence', 'paragraph_id', 'sentence_id_paragraph', 'class_rank', 'score']]
# Out:
#                                    sentence  paragraph_id  \
# 0   我是这么想的：假如我想证明她不是破鞋，就能证明她不是破鞋，那事情未免太容易了。             8
# 1                      原来又有了另一种传闻，说她在和我搞破鞋。            11
# 2                               她说：我什么也没有说。            35
# 3    后来她又改变了主意去找我，是因为所有的人都说她是破鞋，因此所有的人都是敌人。            39
# 4                   我是想研究一下她的结构，这也是在她的许可之下。            47
# 5                           我听了这话不高兴，她也发现了。            48
# 6                            她来的时候，我没有盼着她来。            67
# 7                          可是她说，快，混蛋，还拧我的腿。            72
# 8                             陈清扬说，我叫人惦记上了。            78
# 9                           他还说，我的行为够上了坏分子。            81
# 10                             她说是吗，我自己不知道。            84
# 11                         谁知陈清扬说，她要和我一起逃跑。            93
# 12                            她说，做了的事就不怕交待。           103
# 13           陈清扬说，她女儿已经上了大二，最近知道了我们的事，很想见我。           107
# 14                            她说，暴露就暴露，我不怕。           115
# 15                    过了这么多年我才发现，陈清扬是我的前妻哩。           116
# 16                  我问她，碰上了人家怎么说，她说，她没被碰上过。           120
# 17                  他还让我去告诉我的臭婊子陈清扬，她是如何之坏。           121
# 18                            还有我的猎枪，也不肯还我。           129
# 19                     我走过去坐在她身边，把她的头发撩了起来。           130
# 20                          她说，怎么，还要研究我的结构。           132
# 21                                  我说，怎么了。           137
# 22              陈清扬说，我天资平常，她显然没把我的文学才能考虑在内。           157
# 23                              我吻她的嘴，她没反对。           188
# 24                          陈清扬说，那也是她的黄金时代。           189
# 25                   陈清扬说，她到山里找我时，爬过光秃秃的山岗。           195
# 26        陈清扬说，她到我的小草房里去时，想到了一切东西，就是没想到小和尚。           196
# 27                  陈清扬说，她面对这丑恶的东西，想到了伟大友谊。           198
# 28              但是我在深山里在她屁股上打了两下，彻底玷污了她的清白。           199
# 29            我对陈清扬说，我怎么也想不出来在最后一篇交待里她写了什么。           205
#
#     sentence_id_paragraph class_rank    score
# 0                       1          1  231.181
# 1                       4          1  237.559
# 2                       1          1  269.224
# 3                       4          1  238.451
# 4                       5          1  241.894
# 5                       3          1  243.883
# 6                       3          1  251.814
# 7                       4          1  249.731
# 8                       3          1  249.351
# 9                       2          1  246.096
# 10                     13          1  242.824
# 11                     12          1  245.487
# 12                     13          1  256.191
# 13                      1          1  261.416
# 14                      7          1  261.109
# 15                      1          1  238.641
# 16                     10          1   235.07
# 17                      5          1  232.475
# 18                      6          1  230.732
# 19                      3          1  243.335
# 20                     10          1  264.502
# 21                      5          1  266.906
# 22                      1          1  233.623
# 23                      2          1  252.199
# 24                      1          1  239.078
# 25                      1          1  233.278
# 26                      1          1  233.113
# 27                      1          1  232.641
# 28                      7          1  232.451
# 29                      1          1  232.457

# %% [markdown]
# ### Output results to a file

# %%
'''

with io.open('output_topic_summary.txt','w',encoding='utf8') as f:
    f.write("Original Length : %s" % (len(title) + len(content)))
    f.write("\n")
    f.write("Summary  Length : %s" % len(summary))
    f.write("\n")
    f.write("Summary  Ratio  : %s %%" % (100 * (len(summary) / (len(title) + len(content)))))
    f.write("\n")
    f.write("\n")
    f.write(summary)
    f.close()
    
    '''
# Out:
# '\n\nwith io.open(\'output_topic_summary.txt\',\'w\',encoding=\'utf8\') as f:\n    f.write("Original Length : %s" % (len(title) + len(content)))\n    f.write("\n")\n    f.write("Summary  Length : %s" % len(summary))\n    f.write("\n")\n    f.write("Summary  Ratio  : %s %%" % (100 * (len(summary) / (len(title) + len(content)))))\n    f.write("\n")\n    f.write("\n")\n    f.write(summary)\n    f.close()\n    \n    '
